# %%
from qiskit import QuantumCircuit, Aer, transpile
from qiskit.visualization import plot_histogram

def read_message_from_file(file_path):
    with open(file_path, 'r') as file:
        return file.read().replace('\n', '')

def write_encrypted_message_to_file(file_path, encrypted_message):
    with open(file_path, 'w') as file:
        file.write(encrypted_message)

def write_decrypted_message_to_file(file_path, decrypted_message):
    with open(file_path, 'w') as file:
        file.write(decrypted_message)

def ascii_to_binary(key):
    return ''.join(format(ord(char), '08b') for char in key)

def binary_to_ascii(binary_str):
    return ''.join(chr(int(binary_str[i:i+8], 2)) for i in range(0, len(binary_str), 8))

def quantum_inspired_encryption(message, key):
    key_binary = ascii_to_binary(key)

    # Create a quantum circuit
    qc = QuantumCircuit(len(message) + len(key_binary), len(key_binary))

    # Apply operations based on the key
    for i, bit in enumerate(key_binary):
        if bit == '1':
            qc.x(i)
    qc.barrier()

    # Apply operations based on the message
    for i, bit in enumerate(message):
        if bit == '1':
            qc.x(len(key_binary) + i)
    qc.barrier()

    # Perform CX gates
    for i in range(len(key_binary) - 1):
        qc.cx(i, len(key_binary) + i)
    qc.barrier()

    # Apply Hadamard gates
    for i in range(len(key_binary) + len(message)):
        qc.h(i)
    qc.barrier()

    # Perform measurements
    qc.measure(range(len(key_binary)), range(len(key_binary)))

    # Simulate the quantum circuit
    simulator = Aer.get_backend('qasm_simulator')
    t_qc = transpile(qc, simulator)
    result = simulator.run(t_qc).result()
    counts = result.get_counts(qc)

    # Convert the binary result to a string
    encrypted_message = ''.join(format(int(key, 2), '0'+str(len(key))+'b') for key in counts.keys())

    return encrypted_message

def quantum_inspired_decryption(encrypted_message, key):
    key_binary = ascii_to_binary(key)

    # Create a quantum circuit
    qc = QuantumCircuit(len(encrypted_message), len(key_binary))

    # Apply Hadamard gates
    for i in range(len(key_binary) + len(encrypted_message)):
        qc.h(i)
    qc.barrier()

    # Apply operations based on the key
    for i, bit in enumerate(key_binary):
        if bit == '1':
            qc.x(i)
    qc.barrier()

    # Apply operations based on the encrypted message
    for i, bit in enumerate(encrypted_message):
        if bit == '1':
            qc.x(len(key_binary) + i)
    qc.barrier()

    # Perform CX gates
    for i in range(len(key_binary) - 1):
        qc.cx(i, len(key_binary) + i)
    qc.barrier()

    # Perform measurements
    qc.measure(range(len(key_binary)), range(len(key_binary)))

    # Simulate the quantum circuit
    simulator = Aer.get_backend('qasm_simulator')
    t_qc = transpile(qc, simulator)
    result = simulator.run(t_qc).result()
    counts = result.get_counts(qc)

    # Convert the binary result to a string
    decrypted_message = ''.join(format(int(key, 2), '0'+str(len(key))+'b') for key in counts.keys())

    return decrypted_message

# Test the encryption and decryption
input_file_path = "your_input_file.txt"
encrypted_output_file_path = "encrypted_message.txt"
decrypted_output_file_path = "decrypted_message.txt"

message = read_message_from_file(input_file_path)
key = "YourKey"  # Replace with your ASCII key

encrypted_message = quantum_inspired_encryption(message, key)
write_encrypted_message_to_file(encrypted_output_file_path, encrypted_message)

decrypted_message = quantum_inspired_decryption(encrypted_message, key)
write_decrypted_message_to_file(decrypted_output_file_path, decrypted_message)

print("Original Message:", message)
print("Encrypted Message:", encrypted_message)
print("Decrypted Message:", decrypted_message)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:5624, in _bit_argument_conversion(specifier, bit_sequence, bit_set, type_)
#    5623 try:
# -> 5624     return [bit_sequence[specifier]]
#    5625 except IndexError as ex:
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# CircuitError                              Traceback (most recent call last)
# Cell In[10], line 114
#     111 message = read_message_from_file(input_file_path)
#     112 key = "YourKey"  # Replace with your ASCII key
# --> 114 encrypted_message = quantum_inspired_encryption(message, key)
#     115 write_encrypted_message_to_file(encrypted_output_file_path, encrypted_message)
#     117 decrypted_message = quantum_inspired_decryption(encrypted_message, key)
#
# Cell In[10], line 42, in quantum_inspired_encryption(message, key)
#      40 # Perform CX gates
#      41 for i in range(len(key_binary) - 1):
# ---> 42     qc.cx(i, len(key_binary) + i)
#      43 qc.barrier()
#      45 # Apply Hadamard gates
#
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:3783, in QuantumCircuit.cx(self, control_qubit, target_qubit, label, ctrl_state)
#    3765 r"""Apply :class:`~qiskit.circuit.library.CXGate`.
#    3766
#    3767 For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    3778     A handle to the instructions created.
#    3779 """
#    3781 from .library.standard_gates.x import CXGate
# -> 3783 return self.append(
#    3784     CXGate(label=label, ctrl_state=ctrl_state), [control_qubit, target_qubit], []
#    3785 )
#
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:1273, in QuantumCircuit.append(self, instruction, qargs, cargs)
#    1270     if is_parameter:
#    1271         operation = copy.deepcopy(operation)
# -> 1273 expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
#    1274 expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#    1276 if self._control_flow_scopes:
#
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:1273, in <listcomp>(.0)
#    1270     if is_parameter:
#    1271         operation = copy.deepcopy(operation)
# -> 1273 expanded_qargs = [self.qbit_argument_conversion(qarg) for qarg in qargs or []]
#    1274 expanded_cargs = [self.cbit_argument_conversion(carg) for carg in cargs or []]
#    1276 if self._control_flow_scopes:
#
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:1144, in QuantumCircuit.qbit_argument_conversion(self, qubit_representation)
#    1133 def qbit_argument_conversion(self, qubit_representation: QubitSpecifier) -> list[Qubit]:
#    1134     """
#    1135     Converts several qubit representations (such as indexes, range, etc.)
#    1136     into a list of qubits.
#    (...)
#    1142         List(Qubit): the resolved instances of the qubits.
#    1143     """
# -> 1144     return _bit_argument_conversion(
#    1145         qubit_representation, self.qubits, self._qubit_indices, Qubit
#    1146     )
#
# File E:\anaconda3\Lib\site-packages\qiskit\circuit\quantumcircuit.py:5626, in _bit_argument_conversion(specifier, bit_sequence, bit_set, type_)
#    5624         return [bit_sequence[specifier]]
#    5625     except IndexError as ex:
# -> 5626         raise CircuitError(
#    5627             f"Index {specifier} out of range for size {len(bit_sequence)}."
#    5628         ) from ex
#    5629 # Slices can't raise IndexError - they just return an empty list.
#    5630 if isinstance(specifier, slice):
#
# CircuitError: 'Index 61 out of range for size 61.'
